# %% [markdown]
# 30.08
#
# WE started from GitHub
#
# secondly we talked about Visual Studio code functions
#
# thirdly we tryed to communicate with terminal and jupyther lab

# %% [markdown]
# 13.09
#
#
# повторили материал по векторам: сложение, умножение на скаляр
#
# фиксили гит
#
# отправила работы по код форсу
#
# выполнила домашку по геометрии аналитической
#
# из домашки буду делать сегодня: слау, книжку дочитаю, мб гитхаб оформлю

# %% [markdown]
# 13.09-26.09
#
# введение numpy c matplotlib
#
# сигмы
#
# алгоритмы

# %% [markdown]
# 26.09
#
# Безвучный вызов функции _call_
#
# Что с++ из с
#
# Broadcast/транслирование
#
# np.dot внутреннее произведение векторов при 1D

# %% [markdown]
# 2.10
# np.zeros, nbytes и dtype
