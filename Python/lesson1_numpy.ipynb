# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
v1 = np.array([2,5,4,7])
v2 = np.array([4,1,0,2])
v3 = 4 * v1 - 2 * v2

# %%
v1 = np.array([[2], [3], [5], [6]])
v2 = np.array([[1,2,3,4,]])

# %%
v1 = np.array([2,5,4,7])
plt.axis([3, -1, 3, -1])
plt.plot([0,v1[0]], [0, v1[1]])
v1.T
# Out:
# array([2, 5, 4, 7])

# %%
v1 = np.array([1, 2])
plt.plot([0, v1[0]], [0, v1[1]])
for i in range(10):
    scalar_rand = np.random.randn() 
    scalar_multy = v1 * scalar_rand 
    plt.plot([0, scalar_multy[0]], [0, scalar_multy[1]])
plt.grid("on")  
plt.axis([-4, 4, -4 , 4])
# Out:
# (-4.0, 4.0, -4.0, 4.0)

# %%
import random

for i in range(10):
    scalar_rand = random.randint(3, 9) 
    print(scalar_rand)
# Out:
# 6
# 3
# 5
# 6
# 4
# 7
# 4
# 3
# 3
# 8

# %%
v1 = np.array([2,5,4,7])
v2 = np.array([3,4,5,6])
np.dot(v1, v2) 
plt.axis([0,5,0,6])
# Out:
# (0.0, 5.0, 0.0, 6.0)

# %%
#модуль вектора / норма вектора / высчитывается по формуле евклидова расстояния
v1 = np.array([5,6,7,8,9])  
v_len = len(v1) # математическая размерность
v_len
# Out:
# 5

# %%
v_norm = np.linalg.norm(v1)    #длина или норма вектора, модуль
v_norm
# Out:
# 15.968719422671311

# %%
v1 = np.array([[1, -0], [1, 1]])   
v_unit = np.array([1, 2, 3]) # 3D vecotr
unity_v1 = np.array([1, 0, 0])# первый способ, единичный вектор
unity_v2 = v_unit / v_norm # Второй способ 
print("test", unity_v2, "norma", v_norm)
unit_v1, unity_v3 = np.linalg.eig(v1) # третий способ единичного вектора
unity_vector_norm = np.linalg.norm(v_unit) # длина вектора
unit_v1 
# fig = plt.figure([0, unity_vector_norm[0]], [0, unity_vector_norm[1]], [0, unity_vector_norm[2]]) 
fig, ax = plt.subplots()
ax.quiver(0,0,1,1,angles="xy",scale_units="xy",scale=1)
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
plt.grid()
plt.show()
x_start, y_start, z_start = 0, 0, 0
x_end, y_end, z_end = unity_v1
unit_vector = np.ones(3)

unit_vector
space_3d = fig.add_subplot(111, projection='3d')  

# unit_s
# Out:
# test [0.06262243 0.12524486 0.18786729] norma 15.968719422671311

# %%
#plt.plot([0, unity_vector_norm[0]], [0, unity_vector_norm[1]], [0, unity_vector_norm[2]])
