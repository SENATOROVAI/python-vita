# %%
arbuz:
    
    
w = int(input()) 
if w % 2 == 0 and w > 2:
    print("YES")
else:
    print('NO')
# Out:
#   Cell In[1], line 1
#     arbuz:
#           ^
# SyntaxError: invalid syntax

# %%
Солдат и бананы 

first_b, soldiers_money, how_many = map(int, input().split()) 
cost = 0
for i in range(1, how_many+1):
    banana_cost = i * first_b
    cost += banana_cost
if soldiers_money >= cost:
    print(0)
else:
    print(cost - soldiers_money)
# Out:
#   Cell In[2], line 1
#     Солдат и бананы
#            ^
# SyntaxError: invalid syntax

# %%
elefant 

point_b = int(input())
step = point_b // 5
if point_b % 5:
    step += 1
print(step)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 elefant
#
# NameError: name 'elefant' is not defined
